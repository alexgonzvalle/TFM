# %%
import pandas as pd
pd.options.display.float_format = '{:.4f}'.format

# %%
df_res = pd.read_csv('res.csv')
df_res[df_res['Modelo'] == 'Red_Neuronal']
# Out:
#               Nombre        Modelo  bias_gow  bias_cop  rmse_gow  rmse_cop  \
# 60    Bilbao-Vizcaya  Red_Neuronal    0.0552   -0.0313    0.3902    0.3762
# 61    Cabo_de_Pennas  Red_Neuronal   -0.1227   -0.1751    0.4268    0.4368
# 62   Estaca_de_Bares  Red_Neuronal    0.0316   -0.0397    0.4127    0.3938
# 63  Villano-Sisargas  Red_Neuronal    0.0745   -0.1060    0.4121    0.4091
# 64     Cabo_Silleiro  Red_Neuronal    0.0003   -0.1473    0.3791    0.4057
# 65    Golfo_de_Cadiz  Red_Neuronal   -0.0154   -0.0492    0.2386    0.3147
# 66      Cabo_de_Gata  Red_Neuronal    0.0090   -0.0171    0.2854    0.3044
# 67     Cabo_de_Palos  Red_Neuronal    0.0020    0.0175    0.2616    0.2780
# 68          Valencia  Red_Neuronal    0.0058    0.0303    0.2528    0.2712
# 69         Tarragona  Red_Neuronal   -0.0039   -0.0001    0.2258    0.2763
# 70        Cabo_Begur  Red_Neuronal    0.0397    0.0949    0.3118    0.4331
# ...

# %%
for column in df_res:
    if column != 'Nombre' and column != 'Modelo':
        print(f"{column}: {df_res[df_res['Modelo'] == 'Red_Neuronal'][column].mean():.4f}")
# Out:
# bias_gow: -0.0046
# bias_cop: -0.0345
# rmse_gow: 0.3083
# rmse_cop: 0.3367
# pearson_gow: 0.9312
# pearson_cop: 0.9184
# si_gow: 0.2162
# si_cop: 0.2412
