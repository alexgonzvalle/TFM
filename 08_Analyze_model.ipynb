# %%
import pandas as pd
pd.options.display.float_format = '{:.4f}'.format

# %%
df = pd.read_csv('out_model_red.csv')

# Ordenar por 'loc', 'model' y 'mse'
df = df.sort_values(by=['loc', 'model', 'mse'], ascending=[True, True, True])
# df
# Crear la columna de ranking
df['rank'] = df.groupby(['loc', 'model'])['mse'].rank(method='first')

# Asegurarte de que los rankings sean enteros
df['rank'] = df['rank'].astype(int)

df_grouped = df.groupby(['optimizer', 'n_layers', 'n_neurons']).agg(
    learning_rate=('learning_rate', 'min'),
    ranking=('rank', 'sum')
).reset_index()
df_grouped.sort_values(by=['ranking'], ascending=[True])
# Out:
#    optimizer  n_layers  n_neurons  learning_rate  ranking
# 35       sgd         1        200         0.0064       94
# 34       sgd         1        100         0.0064       94
# 33       sgd         1         50         0.0063      120
# 1       adam         1         50         0.0074      187
# 32       sgd         1         10         0.0067      205
# 0       adam         1         10         0.0064      210
# 3       adam         1        200         0.0070      210
# 16   rmsprop         1         10         0.0075      216
# 2       adam         1        100         0.0072      219
# 19   rmsprop         1        200         0.0074      261
# 17   rmsprop         1         50         0.0074      261
# 18   rmsprop         1        100         0.0073      278
# 39       sgd         5        200         0.0078      434
# 7       adam         5        200         0.0089      469
# 38       sgd         5        100         0.0086      536
# 23   rmsprop         5        200         0.0074      551
# 42       sgd        10        100         0.0072      555
# 6       adam         5        100         0.0089      585
# 43       sgd        10        200         0.0087      629
# 27   rmsprop        10        200         0.0085      629
# 22   rmsprop         5        100         0.0087      664
# 41       sgd        10         50         0.0085      667
# 37       sgd         5         50         0.0088      703
# 26   rmsprop        10        100         0.0089      752
# 21   rmsprop         5         50         0.0087      791
# 45       sgd        15         50         0.0085      837
# 5       adam         5         50         0.0089      865
# 25   rmsprop        10         50         0.0089      868
# 47       sgd        15        200         0.0086      876
# 10      adam        10        100         0.0088      892
# 9       adam        10         50         0.0089      909
# 46       sgd        15        100         0.0087      916
# 36       sgd         5         10         0.0088      985
# 11      adam        10        200         0.0087      987
# 29   rmsprop        15         50         0.0089      988
# 20   rmsprop         5         10         0.0087     1030
# 4       adam         5         10         0.0089     1064
# 30   rmsprop        15        100         0.0072     1092
# 40       sgd        10         10         0.0088     1188
# 13      adam        15         50         0.0083     1204
# 28   rmsprop        15         10         0.0072     1245
# 24   rmsprop        10         10         0.0080     1247
# 8       adam        10         10         0.0085     1255
# 44       sgd        15         10         0.0084     1259
# 31   rmsprop        15        200         0.0072     1290
# 15      adam        15        200         0.0057     1308
# 14      adam        15        100         0.0089     1320
# 12      adam        15         10         0.0088     1335

# %%
df = pd.read_csv('out_model_kmeans.csv')

# Ordenar por 'loc', 'model' y 'mse'
df = df.sort_values(by=['loc', 'model', 'mse'], ascending=[True, True, True])

# Crear la columna de ranking
df['rank'] = df.groupby(['loc', 'model'])['mse'].rank(method='first')

# Asegurarte de que los rankings sean enteros
df['rank'] = df['rank'].astype(int)

df_grouped = df.groupby(['k']).agg(
    ranking=('rank', 'sum')
).reset_index()
df_grouped.sort_values(by=['ranking'], ascending=[True])
# Out:
#        k  ranking
# 198  200     3389
# 199  201     3484
# 202  204     3558
# 175  177     3572
# 203  205     3601
# ..   ...      ...
# 497  499    12632
# 496  498    12666
# 494  496    12670
# 495  497    12743
# 498  500    12827
#
# [499 rows x 2 columns]
